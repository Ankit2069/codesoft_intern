# %% [markdown]
# ## MOVIE RATING PREDICTION WITH PYTHON

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
data = pd.read_csv("prediction.csv", encoding="latin1")
data
# Out:
#                                      Name    Year Duration            Genre  \
# 0                                             NaN      NaN            Drama
# 1      #Gadhvi (He thought he was Gandhi)  (2019)  109 min            Drama
# 2                             #Homecoming  (2021)   90 min   Drama, Musical
# 3                                 #Yaaram  (2019)  110 min  Comedy, Romance
# 4                       ...And Once Again  (2010)  105 min            Drama
# ...                                   ...     ...      ...              ...
# 15504                 Zulm Ko Jala Doonga  (1988)      NaN           Action
# 15505                               Zulmi  (1999)  129 min    Action, Drama
# 15506                           Zulmi Raj  (2005)      NaN           Action
# 15507                       Zulmi Shikari  (1988)      NaN           Action
# 15508                        Zulm-O-Sitam  (1998)  130 min    Action, Drama
#
# ...

# %%
data.head()
# Out:
#                                  Name    Year Duration            Genre  \
# 0                                         NaN      NaN            Drama
# 1  #Gadhvi (He thought he was Gandhi)  (2019)  109 min            Drama
# 2                         #Homecoming  (2021)   90 min   Drama, Musical
# 3                             #Yaaram  (2019)  110 min  Comedy, Romance
# 4                   ...And Once Again  (2010)  105 min            Drama
#
#    Rating Votes            Director       Actor 1             Actor 2  \
# 0     NaN   NaN       J.S. Randhawa      Manmauji              Birbal
# 1     7.0     8       Gaurav Bakshi  Rasika Dugal      Vivek Ghamande
# 2     NaN   NaN  Soumyajit Majumdar  Sayani Gupta   Plabita Borthakur
# 3     4.4    35          Ovais Khan       Prateik          Ishita Raj
# 4     NaN   NaN        Amol Palekar  Rajat Kapoor  Rituparna Sengupta
#
#            Actor 3
# 0  Rajendra Bhatia
# 1    Arvind Jangid
# 2       Roy Angana
# 3  Siddhant Kapoor
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15509 entries, 0 to 15508
# Data columns (total 10 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      15509 non-null  object
#  1   Year      14981 non-null  object
#  2   Duration  7240 non-null   object
#  3   Genre     13632 non-null  object
#  4   Rating    7919 non-null   float64
#  5   Votes     7920 non-null   object
#  6   Director  14984 non-null  object
#  7   Actor 1   13892 non-null  object
#  8   Actor 2   13125 non-null  object
#  9   Actor 3   12365 non-null  object
# dtypes: float64(1), object(9)
# memory usage: 1.2+ MB

# %%
data.describe()
# Out:
#             Rating
# count  7919.000000
# mean      5.841621
# std       1.381777
# min       1.100000
# 25%       4.900000
# 50%       6.000000
# 75%       6.800000
# max      10.000000

# %%
data.shape
# Out:
# (15509, 10)

# %%
data.isnull().sum()
# Out:
# Name           0
# Year         528
# Duration    8269
# Genre       1877
# Rating      7590
# Votes       7589
# Director     525
# Actor 1     1617
# Actor 2     2384
# Actor 3     3144
# dtype: int64

# %%
data.dropna(subset=["Rating"], inplace = True)

# %%
data.isnull().sum()
# Out:
# Name           0
# Year           0
# Duration    2068
# Genre        102
# Rating         0
# Votes          0
# Director       5
# Actor 1      125
# Actor 2      200
# Actor 3      292
# dtype: int64

# %%
data.dropna(subset=['Actor 1','Actor 2','Actor 3','Director','Genre'],inplace=True)

# %%
data.isnull().sum()
# Out:
# Name           0
# Year           0
# Duration    1899
# Genre          0
# Rating         0
# Votes          0
# Director       0
# Actor 1        0
# Actor 2        0
# Actor 3        0
# dtype: int64

# %% [markdown]
# # converting data & removing commas

# %%
data['Votes'] =data['Votes'].str.replace(',','').astype(int)

# %%
data['Year'] =data['Year'].str.strip('()').astype(int)

# %%
data['Duration'] =data['Duration'].str.strip('min')

# %%
data['Duration'].fillna(data['Duration'].median(),inplace=True)

# %%
data.isnull().sum()
# Out:
# Name        0
# Year        0
# Duration    0
# Genre       0
# Rating      0
# Votes       0
# Director    0
# Actor 1     0
# Actor 2     0
# Actor 3     0
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7558 entries, 1 to 15508
# Data columns (total 10 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      7558 non-null   object
#  1   Year      7558 non-null   int32
#  2   Duration  7558 non-null   object
#  3   Genre     7558 non-null   object
#  4   Rating    7558 non-null   float64
#  5   Votes     7558 non-null   int32
#  6   Director  7558 non-null   object
#  7   Actor 1   7558 non-null   object
#  8   Actor 2   7558 non-null   object
#  9   Actor 3   7558 non-null   object
# dtypes: float64(1), int32(2), object(7)
# memory usage: 590.5+ KB

# %% [markdown]
# ## EDA

# %%
top =data.loc[data['Rating'].sort_values(ascending=False)[:10].index]
top
# Out:
#                       Name  Year Duration                   Genre  Rating  \
# 8339       Love Qubool Hai  2020      94           Drama, Romance    10.0
# 5410            Half Songs  2021      79           Music, Romance     9.7
# 2563                 Breed  2020    135.0                   Drama     9.6
# 14222  The Reluctant Crime  2020     113                    Drama     9.4
# 5077          Gho Gho Rani  2019     105         History, Romance     9.4
# 6852                  June  2021      93                    Drama     9.4
# 12673   Secrets of Sinauli  2021      56     Documentary, History     9.3
# 5125           God of gods  2019      90              Documentary     9.3
# 8344          Love Sorries  2021     101   Comedy, Drama, Romance     9.3
# 1314          Ashok Vatika  2018      97                    Drama     9.3
#
#        Votes         Director            Actor 1          Actor 2  \
# 8339       5  Saif Ali Sayeed          Ahaan Jha   Mahesh Narayan
# ...

# %%
sns.histplot(data=top, x="Year",hue="Rating", multiple="stack")
plt.title('Distribution of Top 10', fontsize=14)
plt.xlabel('Year', fontsize=12)
plt.ylabel('Rating', fontsize=12)
plt.tight_layout()
plt.show()

# %%
genre = data['Genre']

# %%
genre.head(11)
# Out:
# 1                         Drama
# 3               Comedy, Romance
# 5        Comedy, Drama, Musical
# 6           Drama, Romance, War
# 8     Horror, Mystery, Thriller
# 9       Action, Crime, Thriller
# 10                        Drama
# 11                       Horror
# 12    Horror, Romance, Thriller
# 13       Comedy, Drama, Romance
# 15                Comedy, Drama
# Name: Genre, dtype: object

# %%
genres = data['Genre'].str.split(', ', expand=True)

# %%
genres.head(11)
# Out:
#          0        1         2
# 1    Drama     None      None
# 3   Comedy  Romance      None
# 5   Comedy    Drama   Musical
# 6    Drama  Romance       War
# 8   Horror  Mystery  Thriller
# 9   Action    Crime  Thriller
# 10   Drama     None      None
# 11  Horror     None      None
# 12  Horror  Romance  Thriller
# 13  Comedy    Drama   Romance
# 15  Comedy    Drama      None

# %%
genre_counts = data['Genre'].value_counts().reset_index()
genre_counts.columns = ['Genre', 'Count']

# %%
top_genres = genre_counts.head(5)
top_genres
# Out:
#                   Genre  Count
# 0                 Drama   1137
# 1        Drama, Romance    443
# 2  Action, Crime, Drama    417
# 3                Action    391
# 4         Drama, Family    291

# %%
plt.figure(figsize=(4, 4))
plt.pie(top_genres['Count'], labels=top_genres['Genre'], autopct='%1.1f%%', startangle=140, colors=sns.color_palette('pastel'))
plt.title('Movie Genre Distribution', fontsize=14)
plt.axis('equal')
plt.show()

# %%
director_avg_rating = data.groupby('Director')['Rating'].mean().reset_index()

director_avg_rating = director_avg_rating.sort_values(by='Rating', ascending=False)

top_directors = director_avg_rating.head(10)
top_directors
# Out:
#              Director  Rating
# 2243  Saif Ali Sayeed    10.0
# 2560      Sriram Raja     9.7
# 504       Bobby Kumar     9.6
# 322     Arvind Pratap     9.4
# 1513     Munni Pankaj     9.4
# 2598   Suhrud Godbole     9.4
# 1601     Nikhil Mahar     9.3
# 2809     Venkatesh Bk     9.3
# 1879    Rahul Mallick     9.3
# 1864   Raghav Jairath     9.3

# %%
plt.figure(figsize=(12, 6))
sns.barplot(data=top_directors, x='Rating', y='Director')

plt.title('Top Directors by Average Rating', fontsize=16)
plt.xlabel('Average Rating', fontsize=14)
plt.ylabel('Director', fontsize=14)

plt.show()

# %%
plt.figure(figsize=(12, 6))
sns.lineplot(data=data, x='Rating', y='Votes')

plt.title('Votes vs. Rating', fontsize=16)
plt.xlabel('Rating', fontsize=14)
plt.ylabel('Votes', fontsize=14)

plt.show()

# %%
ax = sns.boxplot(data=data, y='Year')
ax.set_ylabel('Year')
ax.set_title('Box Plot of Year')
plt.show()

# %% [markdown]
# # Distribution

# %%
new_df = data[(data['Rating'] > 8) & (data['Votes'] > 10000)]
new_df.head(5)
# Out:
#                  Name  Year Duration                    Genre  Rating   Votes  \
# 75           3 Idiots  2009     170             Comedy, Drama     8.4  357889
# 173       A Wednesday  2008     104      Action, Crime, Drama     8.1   75118
# 981             Anand  1971     122            Drama, Musical     8.3   31937
# 1009  Andaz Apna Apna  1994     160   Action, Comedy, Romance     8.1   50810
# 1019        Andhadhun  2018     139       Crime, Drama, Music     8.2   77901
#
#                   Director             Actor 1           Actor 2  \
# 75         Rajkumar Hirani          Aamir Khan          Madhavan
# 173          Neeraj Pandey         Anupam Kher  Naseeruddin Shah
# 981   Hrishikesh Mukherjee       Rajesh Khanna  Amitabh Bachchan
# 1009     Rajkumar Santoshi          Aamir Khan       Salman Khan
# 1019       Sriram Raghavan  Ayushmann Khurrana              Tabu
#
#               Actor 3
# 75         Mona Singh
# 173   Jimmy Sheirgill
# 981     Sumita Sanyal
# ...

# %%
plt.figure(figsize=(15, 6))
ax=sns.barplot(data=new_df,x='Name',y='Votes',hue='Rating')

ax.set_xticklabels(ax.get_xticklabels(), rotation=90, ha='right')
ax.legend(loc='upper right')
ax.set_xlabel('Movie Name')
ax.set_ylabel('Votes')
ax.set_title('Movies with rating greater than 8 and votes greater than 10000')

plt.show()

# %%
data['Duration'] = data['Duration'].astype(int)
data['Year'] = data['Year'].astype(int)


plt.figure(figsize=(12, 6))
sns.lineplot(data=data,x='Year',y='Duration')
plt.xlabel('Year')
plt.ylabel('Duration in minutes')
plt.title('Duration of movies by year')
plt.xticks(np.arange(1917,2023,5))
plt.show()

# %% [markdown]
# # Featured Engineering

# %%
from sklearn.preprocessing import LabelEncoder
labelencoder = LabelEncoder()

t_data = data.drop(['Name'],axis=1)
t_data['Director'] = labelencoder.fit_transform(data['Director'])

t_data['Actor 1'] = labelencoder.fit_transform(data['Actor 1'])
t_data['Actor 2'] = labelencoder.fit_transform(data['Actor 2'])
t_data['Actor 3'] = labelencoder.fit_transform(data['Actor 3'])

t_data['Genre'] = labelencoder.fit_transform(data['Genre'].apply(lambda x: ', '.join(x)))

t_data.head()
# Out:
#    Year  Duration  Genre  Rating  Votes  Director  Actor 1  Actor 2  Actor 3
# 1  2019       109    252     7.0      8       755     1686     2725      373
# 3  2019       110    205     4.4     35      1637     1500      865     2543
# 5  1997       147    175     4.7    827      1881      481       84     2422
# 6  2005       142    315     7.4   1086      2486      878     1346     2996
# 8  2012        82    351     5.6    326       161     2385     1416     1189

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()
sc_data = scaler.fit_transform(t_data)
sc_df = pd.DataFrame(sc_data,columns=t_data.columns)

sc_df.head()
# Out:
#        Year  Duration     Genre    Rating     Votes  Director   Actor 1  \
# 0  0.980769  0.293333  0.607229  0.662921  0.000005  0.255499  0.698426
# 1  0.980769  0.296667  0.493976  0.370787  0.000051  0.553976  0.621375
# 2  0.769231  0.420000  0.421687  0.404494  0.001390  0.636548  0.199254
# 3  0.846154  0.403333  0.759036  0.707865  0.001828  0.841286  0.363712
# 4  0.913462  0.203333  0.845783  0.505618  0.000543  0.054484  0.987987
#
#     Actor 2   Actor 3
# 0  0.979511  0.123102
# 1  0.310927  0.839274
# 2  0.030194  0.799340
# 3  0.483825  0.988779
# 4  0.508986  0.392409

# %% [markdown]
# ## MODEL BUILDING

# %%
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeRegressor
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error,mean_absolute_error,r2_score

# %%
X = t_data.drop(['Rating'],axis=1)

y = t_data['Rating']

X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.25,random_state=40)

model = LinearRegression()
model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
X_test = np.array(X_test)

# %%
X_test
# Out:
# array([[2005,  135,  184, ...,   19,  875, 1328],
#        [2013,  135,  252, ...,  237, 2716,  392],
#        [2006,  180,  314, ..., 1534, 1515, 2043],
#        ...,
#        [1967,  158,  265, ...,  360, 1219, 1908],
#        [1956,  135,    0, ..., 1326, 1426, 1068],
#        [1984,  135,  265, ..., 2053, 2686,  863]])

# %%
y_pred = model.predict(X_test)
y_pred
# Out:
# C:\Users\nanki\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([5.52047941, 5.50379503, 5.61572967, ..., 6.16831668, 6.08912125,
#        6.03829003])

# %%
print('R2 score: ',r2_score(y_test,y_pred))
print('Mean squared error: ',mean_squared_error(y_test,y_pred))
print('Mean absolute error: ',mean_absolute_error(y_test,y_pred))
# Out:
# R2 score:  0.08864632924300164
# Mean squared error:  1.7369607915231626
# Mean absolute error:  1.0474148348950656

# %%
print(y_test)
# Out:
# 13433    5.0
# 11610    6.8
# 14695    4.1
# 12024    7.2
# 10778    6.7
#         ...
# 1038     6.4
# 2612     6.0
# 9901     6.3
# 12331    6.4
# 11437    7.1
# Name: Rating, Length: 1890, dtype: float64
